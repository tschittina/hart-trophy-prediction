# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/skaters.csv')
df = df.drop(columns=['Unnamed: 0'])
df
# Out:
#      vote-share  goals  assists   ops  dps  plus-minus  mvp  position_C  \
# 0         38.43     51       86  11.3  1.3          14    1           1
# 1         30.24     53       84  11.6  2.0          34    0           1
# 2          8.01     50       75  10.8  2.0          40    0           0
# 3          3.64     56       33   8.3  2.1          48    0           0
# 4          1.64     14       61   5.5  5.9          38    0           0
# ..          ...    ...      ...   ...  ...         ...  ...         ...
# 667        1.96     42       52   8.7  2.0           7    0           1
# 668        0.41     23       62   8.0  4.8          12    0           0
# 669        0.15     37       66   9.0  2.7          32    0           1
# 670        0.05     36       53   7.7  3.2          34    0           1
# 671        0.05     57       37  10.0  3.1          29    0           1
#
#      position_D  position_W  points   tps
# 0             0           0     137  12.6
# 1             0           0     137  13.6
# 2             0           1     125  12.8
# 3             0           1      89  10.4
# 4             1           0      75  11.4
# ..          ...         ...     ...   ...
# 667           0           0      94  10.7
# 668           1           0      85  12.8
# 669           0           0     103  11.7
# 670           0           0      89  10.9
# 671           0           0      94  13.1
#
# [672 rows x 12 columns]

# %%
fix, axs = plt.subplots(nrows=2, ncols=2, figsize = (12,8))
axs[0,0].scatter(df['ops'], df['vote-share'])
axs[0,0].set_title('OPS (x) vs. VS (y)')

axs[0,1].scatter(df['dps'], df['vote-share'])
axs[0,1].set_title('DPS (x) vs. VS (y)')

axs[1,0].scatter(df['tps'], df['vote-share'])
axs[1,0].set_title('TPS (x) vs. VS (y)')

axs[1,1].scatter(df['plus-minus'], df['vote-share'])
axs[1,1].set_title('+/- (x) vs. VS (y)')

plt.show()

# %%
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(12,8))

axs[0,0].scatter(df['goals'], df['vote-share'])
axs[0,0].set_title('Goals (x) vs. VS (y)')

axs[0,1].scatter(df['assists'], df['vote-share'])
axs[0,1].set_title('Goals (x) vs. VS (y)')

axs[1,0].scatter(df['points'], df['vote-share'])
axs[1,0].set_title('Points (x) vs. VS (y)')

plt.show()
