# %%
import pandas as pd

# %%
df = pd.read_csv('hart_data.csv')
df
# Out:
#          player names  vote-share position  goals  assists   ops  dps  \
# 0       Wayne Gretzky       38.43        C     51       86  11.3  1.3
# 1       Marcel Dionne       30.24        C     53       84  11.6  2.0
# 2       Tony Esposito       11.66        G      0        1   0.0  0.0
# 3         Guy Lafleur        8.01       RW     50       75  10.8  2.0
# 4          Danny Gare        3.64       RW     56       33   8.3  2.1
# ..                ...         ...      ...    ...      ...   ...  ...
# 847        Roman Josi        0.41        D     23       62   8.0  4.8
# 848       J.T. Miller        0.15        C     37       66   9.0  2.7
# 849     Sebastian Aho        0.05        F     36       53   7.7  3.2
# 850  Charlie Lindgren        0.05        G      0        0   0.0  0.0
# 851      Sam Reinhart        0.05        C     57       37  10.0  3.1
#
#      plus-minus  year
# 0          14.0  1980
# 1          34.0  1980
# 2           0.0  1980
# 3          40.0  1980
# ...
